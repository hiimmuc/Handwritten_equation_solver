# %%
# !nvidia-smi
# Out:
# Fri Oct 16 09:38:26 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.23.05    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8    28W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# 4/5QF2SrjrzPEXzqLNbSh8sMV45w75MxXk2lnYMotcWJJ3vHPCx61StLo

# %% [markdown]
# Clone Darknet

# %% [markdown]
# Compile Darknet

# %%
# %cd /content/drive/My Drive/Final Project/Khang/darknet
# !make
# Out:
# /content/drive/My Drive/Final Project/Khang/darknet
# chmod +x *.sh

# %%
import glob
image_list = glob.glob("data/obj/equation/*.jpg")
print(len(image_list))
# Out:
# 285

# %%
# import random
# #Shuffle
# random.shuffle(image_list)
# #Split data train, data_test (8:2)
# image_training = image_list[:int(0.8 * len(image_list))]
# print(len(image_training))
# image_testing = image_list[int(0.8* len(image_list)):]
# print(len(image_testing))
# #Write to file .txt
file_train = open('data/train_1.txt','w')
file_train.write("\n".join(image_list))
file_train.close()

# file_test = open('data/test.txt','w')
# file_test.write("\n".join(image_testing))
# file_test.close()

# %%
# !sudo chmod +x darknet
# !./darknet detector train data/obj.data cfg/yolov4_training.cfg yolov4.conv.137 -dont_show > yolo_v4.log
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.841397, GIOU: 0.838833), Class: 0.998813, Obj: 0.823224, No Obj: 0.000597, .5R: 1.000000, .75R: 0.875000, count: 16, class_loss = 1.352126, iou_loss = 37.403633, total_loss = 38.755760
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.839664, GIOU: 0.836082), Class: 0.999056, Obj: 0.881721, No Obj: 0.010242, .5R: 1.000000, .75R: 0.882353, count: 85, class_loss = 1.503928, iou_loss = 101.450058, total_loss = 102.953987
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.842138, GIOU: 0.839704), Class: 0.999498, Obj: 0.944029, No Obj: 0.010188, .5R: 1.000000, .75R: 0.950000, count: 20, class_loss = 0.036180, iou_loss = 6.683884, total_loss = 6.720064
#  total_bbox = 4776367, rewritten_bbox = 0.074010 %
# ...
